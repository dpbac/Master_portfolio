# %% [markdown]
# Danielle Paes Barretto de Arruda Camara
#
# **Version: 30/07/19 (last review)**
#
# Statistical analysis of the built playlists.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import time
TodaysDate = time.strftime("%Y-%m-%d")

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# # Folders and Files

# %%
snippets_address_folder = "./data/snippets_address/"
creating_playlist_folder = "./data/creating_playlist/"
images_folder = "./data/img/"

# %%
snippets_pop = "snippets_address_pop_2019-06-13.csv"

tracks_file_clean = "audio_tracks_cleaned_pop_2019-06-13.csv"

diff_all = "audio_tracks_diff_ALL_cleaned_pop_2019-06-13.csv"

diff_in_playlists = "audio_tracks_diff_in_playlists_cleaned_pop_2019-06-13.csv"

df_snippets_ll = "df_snippets_ll_pop_l20_h90_2019-06-26.csv"

df_snippets_lh = "df_snippets_lh_pop_l20_h90_2019-06-26.csv"

df_snippets_hl = "df_snippets_hl_pop_l20_h90_2019-06-26.csv"


category = snippets_pop.split('.')[0].split('_')[-2]
category
# Out:
# 'pop'

# %% [markdown]
# # Functions

# %%
def plot_dist_categories_features(category_id, category_id_df, images_folder):
    """ Plot distribution of audio features or absolute difference of audio features, depending 
    of the dataframe used as input
    
    input:
        category_id: name of the category
        category_id_df: dataframe with audio features or absolute difference of audio features
        images_folder: folder to save the image generated (uncomment line at the end of the function to save)
        
    output:
        density plots of audio features or of the absolute difference of audio features of 2-track sequence
        """
    
    fig, axs = plt.subplots(3, 5, figsize = (15,8))
    fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title
    
    fig.suptitle("Density plots for category "+ category_id)
    
    

    sns.kdeplot(category_id_df['acousticness'],shade=True,legend=False,ax=axs[0,0])
    axs[0,0].set_title('acousticness')
    
    sns.kdeplot(category_id_df['danceability'],shade=True,legend=False,ax=axs[0,1])
    axs[0,1].set_title('danceability')
    
    sns.kdeplot(category_id_df['energy'],shade=True,legend=False,ax=axs[0,2])
    axs[0,2].set_title('energy')
    
    sns.kdeplot(category_id_df['valence'],shade=True,legend=False,ax=axs[0,3])
    axs[0,3].set_title('valence')
    
    sns.kdeplot(category_id_df['tempo'],shade=True,legend=False,ax=axs[0,4])
    axs[0,4].set_title('tempo')

    sns.kdeplot(category_id_df['instrumentalness'],legend=False,shade=True,ax=axs[1,0])
    axs[1,0].set_title('instrumentalness')

    sns.kdeplot(category_id_df['key'],shade=True,legend=False,ax=axs[1,1])
    axs[1,1].set_title('key')
    
    sns.kdeplot(category_id_df['mode'],shade=True,legend=False,ax=axs[1,2])
    axs[1,2].set_title('mode')
    
    sns.kdeplot(category_id_df['liveness'],shade=True,legend=False,ax=axs[1,3])
    axs[1,3].set_title('liveness')
    
    sns.kdeplot(category_id_df['loudness'],shade=True,legend=False,ax=axs[1,4])
    axs[1,4].set_title('loudness')
    
    sns.kdeplot(category_id_df['speechiness'],shade=True,legend=False,ax=axs[2,0])
    axs[2,0].set_title('speechiness')

    # removing unnecessary subplots
    
    axs[2,1].set_axis_off()
    axs[2,2].set_axis_off()
    axs[2,3].set_axis_off()
    axs[2,4].set_axis_off()
        
    plt.show()

# saving image in a file

# Uncomment next live to save image in folder:
    
#     plt.savefig(images_folder + "density_plots_category_"+category_id+"_" + TodaysDate +".png")
    
    plt.close()

def plot_dist_categories_diff_features(category_id, category_id_df, images_folder):
    """ Plot distribution of audio features or absolute difference of audio features, depending 
    of the dataframe used as input
    
    input:
        category_id: name of the category
        category_id_df: dataframe with audio features or absolute difference of audio features
        images_folder: folder to save the image generated (uncomment line at the end of the function to save)
        
    output:
        density plots of audio features or of the absolute difference of audio features of 2-track sequence
        """
    
    fig, axs = plt.subplots(3, 5, figsize = (15,8))
    fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title
    
    fig.suptitle("Density plots for category "+ category_id)
    
    

    sns.kdeplot(category_id_df['diff_acousticness'],shade=True,legend=False,ax=axs[0,0])
    axs[0,0].set_title('diff_acousticness')
    
    sns.kdeplot(category_id_df['diff_danceability'],shade=True,legend=False,ax=axs[0,1])
    axs[0,1].set_title('diff_danceability')
    
    sns.kdeplot(category_id_df['diff_energy'],shade=True,legend=False,ax=axs[0,2])
    axs[0,2].set_title('diff_energy')
    
    sns.kdeplot(category_id_df['diff_valence'],shade=True,legend=False,ax=axs[0,3])
    axs[0,3].set_title('diff_valence')
    
    sns.kdeplot(category_id_df['diff_tempo'],shade=True,legend=False,ax=axs[0,4])
    axs[0,4].set_title('diff_tempo')

    sns.kdeplot(category_id_df['diff_instrumentalness'],legend=False,shade=True,ax=axs[1,0])
    axs[1,0].set_title('diff_instrumentalness')

    sns.kdeplot(category_id_df['diff_key'],shade=True,legend=False,ax=axs[1,1])
    axs[1,1].set_title('diff_key')
    
    sns.kdeplot(category_id_df['diff_mode'],shade=True,legend=False,ax=axs[1,2])
    axs[1,2].set_title('diff_mode')
    
    sns.kdeplot(category_id_df['diff_liveness'],shade=True,legend=False,ax=axs[1,3])
    axs[1,3].set_title('diff_liveness')
    
    sns.kdeplot(category_id_df['diff_loudness'],shade=True,legend=False,ax=axs[1,4])
    axs[1,4].set_title('diff_loudness')
    
    sns.kdeplot(category_id_df['diff_speechiness'],shade=True,legend=False,ax=axs[2,0])
    axs[2,0].set_title('diff_speechiness')

    # removing unnecessary subplots
    
    axs[2,1].set_axis_off()
    axs[2,2].set_axis_off()
    axs[2,3].set_axis_off()
    axs[2,4].set_axis_off()
        
    plt.show()

# saving image in a file

# Uncomment next live to save image in folder:
    
#     plt.savefig(images_folder + "density_plots_category_"+category_id+"_" + TodaysDate +".png")
    
    plt.close()

def frange(start, stop, step):
    """ to use range with decimal numbers"""

    i = start
    while i < stop:
        yield round(i,2)
        i += step

# %% [markdown]
# # Analysis Playlists

# %%
# load audio tracks information

df_tracks = pd.read_csv(creating_playlist_folder+tracks_file_clean)

# %%
# loading info about absolute difference of audio features for all tracks 

df_tracks_diff = pd.read_csv(creating_playlist_folder+diff_all)

# %% [markdown]
# ## Playlist low_low_extreme

# %% [markdown]
# ### Analysis Audio Features Tracks - Playlist  low_low_extreme

# %%
df_snippets_playlist = pd.read_csv(creating_playlist_folder + df_snippets_ll)
df_snippets_playlist
# Out:
#                  track_id                                  track_preview_url
# 0  4vmgP10TH0YYqJkzr8yLW0  https://p.scdn.co/mp3-preview/942ee17ac0cb9871...
# 1  14sOS5L36385FJ3OL8hew4  https://p.scdn.co/mp3-preview/a2c9677593d52774...
# 2  2Fap2zMMINCLylSCSGQLEa  https://p.scdn.co/mp3-preview/44c473a4f8b8274a...
# 3  1ymEwygMMg5JwVAnh3C7yY  https://p.scdn.co/mp3-preview/24074255bfe1055e...
# 4  60Q0ZSKKBea7otGijFgrQI  https://p.scdn.co/mp3-preview/c0382da9d6f1ea57...
# 5  7tsHqxfepei1AdLjy93XIv  https://p.scdn.co/mp3-preview/150880560ac7c21c...
# 6  1eN1K7YPRButXU7Mq0V58N  https://p.scdn.co/mp3-preview/0338b316d387ccfb...
# 7  6uaIMhUZXMuT2Zz0vxrFiR  https://p.scdn.co/mp3-preview/928adf2ede516cf2...
# 8  56ev0yPeYbMzfrGCfS2KCr  https://p.scdn.co/mp3-preview/675a84e349312944...
# 9  7Aw2zBxuyMrrPuxugAcZwr  https://p.scdn.co/mp3-preview/a55785a57212caf5...

# %%
tracks_playlist = df_snippets_playlist['track_id']

df_tracks_playlist = df_tracks[df_tracks["track_id"].isin(tracks_playlist)]

df_tracks_playlist.drop_duplicates(subset=['track_id'], keep='first', inplace=True)

# to be sure the information is in the good order
df_tracks_playlist.set_index('track_id',inplace=True)

df_tracks_playlist=df_tracks_playlist.reindex(index = tracks_playlist)

df_tracks_playlist.reset_index(inplace=True)
df_tracks_playlist
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                  track_id category_id               album_name  \
# 0  4vmgP10TH0YYqJkzr8yLW0         pop               On My Mind
# 1  14sOS5L36385FJ3OL8hew4         pop                Happy Now
# 2  2Fap2zMMINCLylSCSGQLEa         pop      Say You'll Be There
# 3  1ymEwygMMg5JwVAnh3C7yY         pop  Thursday (feat. H.E.R.)
# 4  60Q0ZSKKBea7otGijFgrQI         pop               Crazy Life
# 5  7tsHqxfepei1AdLjy93XIv         pop                   Summer
# 6  1eN1K7YPRButXU7Mq0V58N         pop                 Obsessed
# 7  6uaIMhUZXMuT2Zz0vxrFiR         pop     The Woods (Acoustic)
# 8  56ev0yPeYbMzfrGCfS2KCr         pop       Self Sabotage - EP
# 9  7Aw2zBxuyMrrPuxugAcZwr         pop          Hôtel Costes 15
#
#             artist_name       playlist_name               track_name  \
# 0           Liam Bailey           Retro Pop               On My Mind
# 1   Kygo,Sandro Cavazza        Love For Pop                Happy Now
# 2        Campsite Dream        Love For Pop      Say You'll Be There
# 3    Jess Glynne,H.E.R.         Stay Tuned!  Thursday (feat. H.E.R.)
# 4             Home Free      All A Cappella               Wake Me Up
# 5           Chloe Lilac      Left of Center                   Summer
# 6      Maggie Lindemann          Girls Only                 Obsessed
# 7          Hollow Coves       Acoustic Hits     The Woods - Acoustic
# 8                GRAACE  Everyday Favorites                      SOS
# 9  Intergalactic Lovers           Retro Pop                Fade Away
#
#                               track_uri  duration_ms  track_popularity  \
# 0  spotify:track:4vmgP10TH0YYqJkzr8yLW0       213733                33
# 1  spotify:track:14sOS5L36385FJ3OL8hew4       211362                88
# 2  spotify:track:2Fap2zMMINCLylSCSGQLEa       169500                47
# 3  spotify:track:1ymEwygMMg5JwVAnh3C7yY       216297                70
# 4  spotify:track:60Q0ZSKKBea7otGijFgrQI       193733                49
# 5  spotify:track:7tsHqxfepei1AdLjy93XIv       178457                61
# 6  spotify:track:1eN1K7YPRButXU7Mq0V58N       184515                68
# 7  spotify:track:6uaIMhUZXMuT2Zz0vxrFiR       239960                66
# 8  spotify:track:56ev0yPeYbMzfrGCfS2KCr       187547                55
# 9  spotify:track:7Aw2zBxuyMrrPuxugAcZwr       179480                44
#
#    acousticness  danceability  energy  valence    tempo  instrumentalness  \
# 0        0.0103         0.632   0.586    0.509  109.593          0.000021
# 1        0.3740         0.693   0.575    0.492  117.999          0.000000
# 2        0.2100         0.683   0.598    0.468  109.999          0.000147
# 3        0.3160         0.771   0.575    0.419  111.930          0.000000
# 4        0.4770         0.712   0.554    0.369  116.910          0.000000
# 5        0.2820         0.639   0.531    0.318  112.926          0.000001
# 6        0.0182         0.822   0.575    0.286  110.028          0.000044
# 7        0.7220         0.571   0.558    0.283  104.991          0.000331
# 8        0.4160         0.573   0.511    0.287  100.135          0.000017
# 9        0.1320         0.777   0.476    0.335  108.071          0.000000
#
#    key  mode  liveness  loudness  speechiness
# 0    1     1    0.0624    -2.796       0.0443
# 1    9     1    0.2520    -6.998       0.0801
# 2    2     1    0.1240    -7.835       0.0323
# 3    2     1    0.0849    -4.128       0.0513
# 4    3     1    0.1900    -6.672       0.0337
# 5    4     1    0.1110    -5.531       0.0277
# 6    6     0    0.1090    -4.587       0.0464
# 7    9     1    0.1160    -8.553       0.0281
# 8    3     1    0.1660    -9.042       0.0581
# 9    1     1    0.3220    -7.652       0.0561

# %%
df_tracks_playlist.to_csv(creating_playlist_folder+ "playlist_low_low_extreme_info.csv", index=False)

# %% [markdown]
# #### Descriptive Statistics

# %%
df_tracks_playlist[['energy','valence','tempo']].describe()
# Out:
#           energy    valence       tempo
# count  10.000000  10.000000   10.000000
# mean    0.553900   0.376600  110.258200
# std     0.037655   0.088956    5.266747
# min     0.476000   0.283000  100.135000
# 25%     0.536750   0.294750  108.451500
# 50%     0.566500   0.352000  110.013500
# 75%     0.575000   0.455750  112.677000
# max     0.598000   0.509000  117.999000

# %% [markdown]
# #### Boxplot

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots Audio Features : Energy, Valence, and Tempo for Playlist with \n Low Absolute Difference in "+
            "Energy, Valence, and Tempo for Category "+category+".")
    
sns.boxplot(data=df_tracks_playlist[['energy', 'valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter PLot Showing Tracks of Playlist  low_low_extreme

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy,hue = df_tracks_playlist.track_name, s = 200)
ax.set_title('Energy x Valence for tracks in Playlist low_low_extreme.\n', fontsize=16)
# ax.legend(loc = 'best')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.25),ncol=3, fancybox=True, shadow=True)

# %% [markdown]
# #### 3D Scatter plot showing tracks

# %%
df_track_names = df_tracks_playlist.track_name.to_frame()

df_track_names.reset_index(inplace=True)

df_track_names
# Out:
#    index               track_name
# 0      0               On My Mind
# 1      1                Happy Now
# 2      2      Say You'll Be There
# 3      3  Thursday (feat. H.E.R.)
# 4      4               Wake Me Up
# 5      5                   Summer
# 6      6                 Obsessed
# 7      7     The Woods - Acoustic
# 8      8                      SOS
# 9      9                Fade Away

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = df_tracks_playlist.valence
ys = df_tracks_playlist.energy
zs = df_tracks_playlist.tempo

ax.scatter(xs, ys, zs, s=200,c = df_track_names['index'], cmap=cm.tab10)
ax.set_title('Energy x Valence x Tempo for tracks in Playlist low_low_extreme.\n', fontsize=16)

ax.set_xlabel('Valence')
ax.set_ylabel('Energy')
ax.set_zlabel('Tempo')


plt.show()

# %% [markdown]
# #### Density Plots

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots energy, valence, and tempo for Playlist low_low_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['energy', 'valence', 'tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Analysis Absolute Difference Between Audio Tracks - Playlist  low_low_extreme

# %%
list_current = df_snippets_playlist['track_id'][:-1].tolist()
list_next = df_snippets_playlist['track_id'][1:].tolist()

df_diff_playlist = pd.DataFrame(data = {'current_track':list_current,'next_track':list_next})
df_diff_playlist["current_track-next_track"] = df_diff_playlist['current_track']+'_'+df_diff_playlist['next_track']
df_diff_playlist.head()
# Out:
#             current_track              next_track  \
# 0  4vmgP10TH0YYqJkzr8yLW0  14sOS5L36385FJ3OL8hew4
# 1  14sOS5L36385FJ3OL8hew4  2Fap2zMMINCLylSCSGQLEa
# 2  2Fap2zMMINCLylSCSGQLEa  1ymEwygMMg5JwVAnh3C7yY
# 3  1ymEwygMMg5JwVAnh3C7yY  60Q0ZSKKBea7otGijFgrQI
# 4  60Q0ZSKKBea7otGijFgrQI  7tsHqxfepei1AdLjy93XIv
#
#                         current_track-next_track
# 0  4vmgP10TH0YYqJkzr8yLW0_14sOS5L36385FJ3OL8hew4
# 1  14sOS5L36385FJ3OL8hew4_2Fap2zMMINCLylSCSGQLEa
# 2  2Fap2zMMINCLylSCSGQLEa_1ymEwygMMg5JwVAnh3C7yY
# 3  1ymEwygMMg5JwVAnh3C7yY_60Q0ZSKKBea7otGijFgrQI
# 4  60Q0ZSKKBea7otGijFgrQI_7tsHqxfepei1AdLjy93XIv

# %%
list_sequences = df_diff_playlist["current_track-next_track"].tolist()

# %%
audio_features_df = df_tracks_diff[df_tracks_diff["current_track-next_track"].isin(list_sequences)]

# %%
df_tracks_playlist = pd.merge(df_diff_playlist,audio_features_df,left_on="current_track-next_track", right_on="current_track-next_track")

# %%
df_tracks_playlist
# Out:
#             current_track              next_track  \
# 0  4vmgP10TH0YYqJkzr8yLW0  14sOS5L36385FJ3OL8hew4
# 1  14sOS5L36385FJ3OL8hew4  2Fap2zMMINCLylSCSGQLEa
# 2  2Fap2zMMINCLylSCSGQLEa  1ymEwygMMg5JwVAnh3C7yY
# 3  1ymEwygMMg5JwVAnh3C7yY  60Q0ZSKKBea7otGijFgrQI
# 4  60Q0ZSKKBea7otGijFgrQI  7tsHqxfepei1AdLjy93XIv
# 5  7tsHqxfepei1AdLjy93XIv  1eN1K7YPRButXU7Mq0V58N
# 6  1eN1K7YPRButXU7Mq0V58N  6uaIMhUZXMuT2Zz0vxrFiR
# 7  6uaIMhUZXMuT2Zz0vxrFiR  56ev0yPeYbMzfrGCfS2KCr
# 8  56ev0yPeYbMzfrGCfS2KCr  7Aw2zBxuyMrrPuxugAcZwr
#
#                         current_track-next_track  diff_acousticness  \
# 0  4vmgP10TH0YYqJkzr8yLW0_14sOS5L36385FJ3OL8hew4             0.3637
# 1  14sOS5L36385FJ3OL8hew4_2Fap2zMMINCLylSCSGQLEa             0.1640
# 2  2Fap2zMMINCLylSCSGQLEa_1ymEwygMMg5JwVAnh3C7yY             0.1060
# 3  1ymEwygMMg5JwVAnh3C7yY_60Q0ZSKKBea7otGijFgrQI             0.1610
# 4  60Q0ZSKKBea7otGijFgrQI_7tsHqxfepei1AdLjy93XIv             0.1950
# 5  7tsHqxfepei1AdLjy93XIv_1eN1K7YPRButXU7Mq0V58N             0.2638
# 6  1eN1K7YPRButXU7Mq0V58N_6uaIMhUZXMuT2Zz0vxrFiR             0.7038
# 7  6uaIMhUZXMuT2Zz0vxrFiR_56ev0yPeYbMzfrGCfS2KCr             0.3060
# 8  56ev0yPeYbMzfrGCfS2KCr_7Aw2zBxuyMrrPuxugAcZwr             0.2840
#
#    diff_danceability  diff_energy  diff_valence  diff_tempo  \
# 0              0.061        0.011         0.017       8.406
# 1              0.010        0.023         0.024       8.000
# 2              0.088        0.023         0.049       1.931
# 3              0.059        0.021         0.050       4.980
# 4              0.073        0.023         0.051       3.984
# 5              0.183        0.044         0.032       2.898
# 6              0.251        0.017         0.003       5.037
# 7              0.002        0.047         0.004       4.856
# 8              0.204        0.035         0.048       7.936
#
#    diff_instrumentalness  diff_key  diff_mode  diff_liveness  diff_loudness  \
# 0               0.000021       8.0        0.0         0.1896          4.202
# 1               0.000147       7.0        0.0         0.1280          0.837
# 2               0.000147       0.0        0.0         0.0391          3.707
# 3               0.000000       1.0        0.0         0.1051          2.544
# 4               0.000001       1.0        0.0         0.0790          1.141
# 5               0.000043       2.0        1.0         0.0020          0.944
# 6               0.000287       3.0        1.0         0.0070          3.966
# 7               0.000314       6.0        0.0         0.0500          0.489
# 8               0.000017       2.0        0.0         0.1560          1.390
#
#    diff_speechiness  is_good_sequence
# 0            0.0358                 0
# 1            0.0478                 0
# 2            0.0190                 0
# 3            0.0176                 0
# 4            0.0060                 0
# 5            0.0187                 0
# 6            0.0183                 0
# 7            0.0300                 0
# 8            0.0020                 0

# %% [markdown]
# #### Descriptive Statistics

# %%
df_tracks_playlist[['diff_energy','diff_valence','diff_tempo']].describe()
# Out:
#        diff_energy  diff_valence  diff_tempo
# count     9.000000      9.000000    9.000000
# mean      0.027111      0.030889    5.336444
# std       0.012211      0.019789    2.320940
# min       0.011000      0.003000    1.931000
# 25%       0.021000      0.017000    3.984000
# 50%       0.023000      0.032000    4.980000
# 75%       0.035000      0.049000    7.936000
# max       0.047000      0.051000    8.406000

# %% [markdown]
# #### Boxplots

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots audio features : diff_energy, diff_valence, and diff_tempo.")
    
sns.boxplot(data=df_tracks_playlist[['diff_energy', 'diff_valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['diff_tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter plots Valence x Energy Playlist  low_low_extreme

# %%
# sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy)
ax = sns.scatterplot(df_tracks_playlist.diff_valence, df_tracks_playlist.diff_energy, hue = df_tracks_playlist["current_track-next_track"], s = 200, cmap=cm.tab10)
# Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.60),ncol=2, fancybox=True, shadow=True)

# %% [markdown]
# #### Density PLots

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots diff_energy, diff_valence, and diff_tempo for Playlist low_low_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.diff_energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.diff_valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.diff_tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_diff_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['diff_energy', 'diff_valence', 'diff_tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Playlist  low_high_extreme

# %% [markdown]
# ### Analysis Audio Features Tracks - Playlist low_high_extreme

# %%
df_snippets_playlist = pd.read_csv(creating_playlist_folder + df_snippets_lh)
df_snippets_playlist
# Out:
#                  track_id                                  track_preview_url
# 0  2YyvWje3cEYyqgYhNUIaBJ  https://p.scdn.co/mp3-preview/1797c297de1a9896...
# 1  4SX4NUI58M3KhbalXxjwFC  https://p.scdn.co/mp3-preview/f506a04af090fe90...
# 2  2hnxrRNzF74mdDzpQZQukQ  https://p.scdn.co/mp3-preview/ecf605ea149db4f7...
# 3  5GT8b1dFaOWFF5twsmSOYx  https://p.scdn.co/mp3-preview/15075c9698e01a1f...
# 4  1roCmBlcpV7LzsmB7pmCyt  https://p.scdn.co/mp3-preview/e3e9c860e28d0d86...
# 5  2CTN6UuO2dNEVZXR0DJVk2  https://p.scdn.co/mp3-preview/58e0924ae9a2b009...
# 6  708L4ld9wD2pjoqKwaxkXa  https://p.scdn.co/mp3-preview/e452a44a8c4b4ed1...
# 7  5R96PHcqOGjgj23D98F6mf  https://p.scdn.co/mp3-preview/49e482246c72b5e2...
# 8  7pdF27mSDuPWhppnHAmWHa  https://p.scdn.co/mp3-preview/f69b47e8941ef8f4...
# 9  4825x6Yy20mNZ4Ll5XyA9g  https://p.scdn.co/mp3-preview/caa402fd81fff0a8...

# %%
tracks_playlist = df_snippets_playlist['track_id']

df_tracks_playlist = df_tracks[df_tracks["track_id"].isin(tracks_playlist)]

df_tracks_playlist.drop_duplicates(subset=['track_id'], keep='first', inplace=True)

# to be sure the information is in the good order
df_tracks_playlist.set_index('track_id',inplace=True)

df_tracks_playlist=df_tracks_playlist.reindex(index = tracks_playlist)

df_tracks_playlist.reset_index(inplace=True)
df_tracks_playlist
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                  track_id category_id  \
# 0  2YyvWje3cEYyqgYhNUIaBJ         pop
# 1  4SX4NUI58M3KhbalXxjwFC         pop
# 2  2hnxrRNzF74mdDzpQZQukQ         pop
# 3  5GT8b1dFaOWFF5twsmSOYx         pop
# 4  1roCmBlcpV7LzsmB7pmCyt         pop
# 5  2CTN6UuO2dNEVZXR0DJVk2         pop
# 6  708L4ld9wD2pjoqKwaxkXa         pop
# 7  5R96PHcqOGjgj23D98F6mf         pop
# 8  7pdF27mSDuPWhppnHAmWHa         pop
# 9  4825x6Yy20mNZ4Ll5XyA9g         pop
#
#                                 album_name                 artist_name  \
# 0                                 Love, me               Lennon Stella
# 1                                 A Prayer                JNR WILLIAMS
# 2    There's No Way (feat. Julia Michaels)         Lauv,Julia Michaels
# 3                         The Best You Had                Nina Nesbitt
# 4  Let Me Down Slowly (feat. Alessia Cara)  Alec Benjamin,Alessia Cara
# 5                         Phoenix (Deluxe)                    Rita Ora
# 6                             Braver Times                     Someone
# 7                                     Caer       Twin Shadow,Rainsford
# 8                                    SKINS                XXXTENTACION
# 9                         Only Ticket Home                 Gavin James
#
#         playlist_name                               track_name  \
# 0           Pop Sauce                                 La Di Da
# 1         Stay Tuned!                                 A Prayer
# 2        Mega Hit Mix    There's No Way (feat. Julia Michaels)
# 3       Soft Pop Hits                         The Best You Had
# 4    Chilled Pop Hits  Let Me Down Slowly (feat. Alessia Cara)
# 5          Girls Only                            Only Want You
# 6          Troubadour                             Braver Times
# 7      Left of Center                  Brace (feat. Rainsford)
# 8        Hot Rhythmic                       whoa (mind in awe)
# 9  Everyday Favorites                          Cigarette Break
#
#                               track_uri  duration_ms  track_popularity  \
# 0  spotify:track:2YyvWje3cEYyqgYhNUIaBJ       209773                81
# 1  spotify:track:4SX4NUI58M3KhbalXxjwFC       204431                47
# 2  spotify:track:2hnxrRNzF74mdDzpQZQukQ       174861                85
# 3  spotify:track:5GT8b1dFaOWFF5twsmSOYx       175061                70
# 4  spotify:track:1roCmBlcpV7LzsmB7pmCyt       169175                77
# 5  spotify:track:2CTN6UuO2dNEVZXR0DJVk2       180760                79
# 6  spotify:track:708L4ld9wD2pjoqKwaxkXa       271473                27
# 7  spotify:track:5R96PHcqOGjgj23D98F6mf       206561                58
# 8  spotify:track:7pdF27mSDuPWhppnHAmWHa       157777                87
# 9  spotify:track:4825x6Yy20mNZ4Ll5XyA9g       245789                41
#
#    acousticness  danceability  energy  valence    tempo  instrumentalness  \
# 0        0.1950         0.689   0.679    0.475  149.972          0.001110
# 1        0.3220         0.376   0.637    0.438   77.670          0.000000
# 2        0.4900         0.755   0.625    0.374  147.020          0.000000
# 3        0.3580         0.595   0.608    0.452   60.878          0.000000
# 4        0.7160         0.655   0.569    0.440  150.267          0.000007
# 5        0.0599         0.654   0.528    0.376   82.014          0.000071
# 6        0.1680         0.446   0.550    0.319  159.971          0.162000
# 7        0.4170         0.695   0.565    0.302   67.992          0.000037
# 8        0.6530         0.735   0.525    0.369  160.147          0.918000
# 9        0.1270         0.446   0.527    0.331   69.657          0.000000
#
#    key  mode  liveness  loudness  speechiness
# 0    7     1    0.2240    -5.893       0.0517
# 1   10     0    0.0833    -6.701       0.2760
# 2    2     1    0.1570    -7.114       0.0896
# 3    5     0    0.0843    -5.303       0.0373
# 4    1     0    0.1350    -5.018       0.0349
# 5    6     0    0.0975    -6.224       0.0412
# 6    7     1    0.2040    -7.253       0.0301
# 7   10     1    0.0979    -5.806       0.0382
# 8    6     0    0.1010    -2.939       0.0441
# 9    2     1    0.1130    -6.224       0.0347

# %%
df_tracks_playlist.to_csv(creating_playlist_folder+ "playlist_low_high_extreme_info.csv", index=False)

# %% [markdown]
# #### Descriptive Statistics

# %%
df_tracks_playlist[['energy','valence','tempo']].describe()
# Out:
#           energy   valence       tempo
# count  10.000000  10.00000   10.000000
# mean    0.581300   0.38760  112.558800
# std     0.053361   0.06053   43.677691
# min     0.525000   0.30200   60.878000
# 25%     0.533500   0.34050   71.660250
# 50%     0.567000   0.37500  114.517000
# 75%     0.620750   0.43950  150.193250
# max     0.679000   0.47500  160.147000

# %% [markdown]
# #### Boxplot

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots Audio Features : Energy, Valence, and Tempo for Playlist with Low Absolute Difference in"+
            "Energy, Valence, and Tempo for Category "+category+".")
    
sns.boxplot(data=df_tracks_playlist[['energy', 'valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter PLot Showing Tracks of Playlist low_high_extreme

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy,hue = df_tracks_playlist.track_name, s = 200)
ax.set_title('Energy x Valence for tracks in Playlist low_high_extreme.\n', fontsize=16)
# ax.legend(loc = 'best')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.25),ncol=3, fancybox=True, shadow=True)

# %% [markdown]
# #### 3D Scatter plot showing tracks

# %%
df_track_names = df_tracks_playlist.track_name.to_frame()

df_track_names.reset_index(inplace=True)

df_track_names
# Out:
#    index                               track_name
# 0      0                                 La Di Da
# 1      1                                 A Prayer
# 2      2    There's No Way (feat. Julia Michaels)
# 3      3                         The Best You Had
# 4      4  Let Me Down Slowly (feat. Alessia Cara)
# 5      5                            Only Want You
# 6      6                             Braver Times
# 7      7                  Brace (feat. Rainsford)
# 8      8                       whoa (mind in awe)
# 9      9                          Cigarette Break

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = df_tracks_playlist.valence
ys = df_tracks_playlist.energy
zs = df_tracks_playlist.tempo

ax.scatter(xs, ys, zs, s=200,c = df_track_names['index'], cmap=cm.tab10)
ax.set_title('Energy x Valence x Tempo for tracks in Playlist low_high_extreme.\n', fontsize=16)

ax.set_xlabel('Valence')
ax.set_ylabel('Energy')
ax.set_zlabel('Tempo')


plt.show()

# %% [markdown]
# #### Density Plots

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots energy, valence, and tempo for Playlist low_high_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['energy', 'valence', 'tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Analysis Absolute Difference Between Audio Tracks - Playlist low_high_extreme

# %%
list_current = df_snippets_playlist['track_id'][:-1].tolist()
list_next = df_snippets_playlist['track_id'][1:].tolist()

df_diff_playlist = pd.DataFrame(data = {'current_track':list_current,'next_track':list_next})
df_diff_playlist["current_track-next_track"] = df_diff_playlist['current_track']+'_'+df_diff_playlist['next_track']
df_diff_playlist.head()
# Out:
#             current_track              next_track  \
# 0  2YyvWje3cEYyqgYhNUIaBJ  4SX4NUI58M3KhbalXxjwFC
# 1  4SX4NUI58M3KhbalXxjwFC  2hnxrRNzF74mdDzpQZQukQ
# 2  2hnxrRNzF74mdDzpQZQukQ  5GT8b1dFaOWFF5twsmSOYx
# 3  5GT8b1dFaOWFF5twsmSOYx  1roCmBlcpV7LzsmB7pmCyt
# 4  1roCmBlcpV7LzsmB7pmCyt  2CTN6UuO2dNEVZXR0DJVk2
#
#                         current_track-next_track
# 0  2YyvWje3cEYyqgYhNUIaBJ_4SX4NUI58M3KhbalXxjwFC
# 1  4SX4NUI58M3KhbalXxjwFC_2hnxrRNzF74mdDzpQZQukQ
# 2  2hnxrRNzF74mdDzpQZQukQ_5GT8b1dFaOWFF5twsmSOYx
# 3  5GT8b1dFaOWFF5twsmSOYx_1roCmBlcpV7LzsmB7pmCyt
# 4  1roCmBlcpV7LzsmB7pmCyt_2CTN6UuO2dNEVZXR0DJVk2

# %%
list_sequences = df_diff_playlist["current_track-next_track"].tolist()

# %%
audio_features_df = df_tracks_diff[df_tracks_diff["current_track-next_track"].isin(list_sequences)]

# %%
df_tracks_playlist = pd.merge(df_diff_playlist,audio_features_df,left_on="current_track-next_track", right_on="current_track-next_track")

# %%
df_tracks_playlist
# Out:
#             current_track              next_track  \
# 0  2YyvWje3cEYyqgYhNUIaBJ  4SX4NUI58M3KhbalXxjwFC
# 1  4SX4NUI58M3KhbalXxjwFC  2hnxrRNzF74mdDzpQZQukQ
# 2  2hnxrRNzF74mdDzpQZQukQ  5GT8b1dFaOWFF5twsmSOYx
# 3  5GT8b1dFaOWFF5twsmSOYx  1roCmBlcpV7LzsmB7pmCyt
# 4  1roCmBlcpV7LzsmB7pmCyt  2CTN6UuO2dNEVZXR0DJVk2
# 5  2CTN6UuO2dNEVZXR0DJVk2  708L4ld9wD2pjoqKwaxkXa
# 6  708L4ld9wD2pjoqKwaxkXa  5R96PHcqOGjgj23D98F6mf
# 7  5R96PHcqOGjgj23D98F6mf  7pdF27mSDuPWhppnHAmWHa
# 8  7pdF27mSDuPWhppnHAmWHa  4825x6Yy20mNZ4Ll5XyA9g
#
#                         current_track-next_track  diff_acousticness  \
# 0  2YyvWje3cEYyqgYhNUIaBJ_4SX4NUI58M3KhbalXxjwFC             0.1270
# 1  4SX4NUI58M3KhbalXxjwFC_2hnxrRNzF74mdDzpQZQukQ             0.1680
# 2  2hnxrRNzF74mdDzpQZQukQ_5GT8b1dFaOWFF5twsmSOYx             0.1320
# 3  5GT8b1dFaOWFF5twsmSOYx_1roCmBlcpV7LzsmB7pmCyt             0.3580
# 4  1roCmBlcpV7LzsmB7pmCyt_2CTN6UuO2dNEVZXR0DJVk2             0.6561
# 5  2CTN6UuO2dNEVZXR0DJVk2_708L4ld9wD2pjoqKwaxkXa             0.1081
# 6  708L4ld9wD2pjoqKwaxkXa_5R96PHcqOGjgj23D98F6mf             0.2490
# 7  5R96PHcqOGjgj23D98F6mf_7pdF27mSDuPWhppnHAmWHa             0.2360
# 8  7pdF27mSDuPWhppnHAmWHa_4825x6Yy20mNZ4Ll5XyA9g             0.5260
#
#    diff_danceability  diff_energy  diff_valence  diff_tempo  \
# 0              0.313        0.042         0.037      72.302
# 1              0.379        0.012         0.064      69.350
# 2              0.160        0.017         0.078      86.142
# 3              0.060        0.039         0.012      89.389
# 4              0.001        0.041         0.064      68.253
# 5              0.208        0.022         0.057      77.957
# 6              0.249        0.015         0.017      91.979
# 7              0.040        0.040         0.067      92.155
# 8              0.289        0.002         0.038      90.490
#
#    diff_instrumentalness  diff_key  diff_mode  diff_liveness  diff_loudness  \
# 0               0.001110       3.0        1.0         0.1407          0.808
# 1               0.000000       8.0        1.0         0.0737          0.413
# 2               0.000000       3.0        1.0         0.0727          1.811
# 3               0.000007       4.0        0.0         0.0507          0.285
# 4               0.000064       5.0        0.0         0.0375          1.206
# 5               0.161929       1.0        1.0         0.1065          1.029
# 6               0.161963       3.0        0.0         0.1061          1.447
# 7               0.917963       4.0        1.0         0.0031          2.867
# 8               0.918000       4.0        1.0         0.0120          3.285
#
#    diff_speechiness  is_good_sequence
# 0            0.2243                 0
# 1            0.1864                 0
# 2            0.0523                 0
# 3            0.0024                 0
# 4            0.0063                 0
# 5            0.0111                 0
# 6            0.0081                 0
# 7            0.0059                 0
# 8            0.0094                 0

# %% [markdown]
# #### Descriptive Statistics absolute difference 2-tracks

# %%
df_tracks_playlist[['diff_energy','diff_valence','diff_tempo']].describe()
# Out:
#        diff_energy  diff_valence  diff_tempo
# count     9.000000      9.000000    9.000000
# mean      0.025556      0.048222   82.001889
# std       0.015142      0.023269   10.037041
# min       0.002000      0.012000   68.253000
# 25%       0.015000      0.037000   72.302000
# 50%       0.022000      0.057000   86.142000
# 75%       0.040000      0.064000   90.490000
# max       0.042000      0.078000   92.155000

# %% [markdown]
# #### Boxplots absolute difference 2-tracks

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots audio features : diff_energy, diff_valence, and diff_tempo.")
    
sns.boxplot(data=df_tracks_playlist[['diff_energy', 'diff_valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['diff_tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter plots absolute difference 2-tracks Valence x Energy Playlist low_high_extreme

# %%
# sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy)
ax = sns.scatterplot(df_tracks_playlist.diff_valence, df_tracks_playlist.diff_energy, hue = df_tracks_playlist["current_track-next_track"], s = 200, cmap=cm.tab10)
# Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.50),ncol=2, fancybox=True, shadow=True)

# %% [markdown]
# #### Density PLots absolute difference 2-tracks - energy, valence, and tempo

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots absolute difference 2-tracks diff_energy, diff_valence, and diff_tempo for Playlist low_high_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.diff_energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.diff_valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.diff_tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features absolute difference 2-tracks

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_diff_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap absolute difference 2-tracks

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots absolute difference 2-tracks energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['diff_energy', 'diff_valence', 'diff_tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Playlist high_low_extreme

# %% [markdown]
# ### Analysis Audio Features Tracks - Playlist high_low_extreme

# %%
df_snippets_playlist = pd.read_csv(creating_playlist_folder + df_snippets_hl)
df_snippets_playlist
# Out:
#                  track_id                                  track_preview_url
# 0  3y4uSQwxHckyRcvafEilkN  https://p.scdn.co/mp3-preview/49feddf3bd39e3c2...
# 1  0KURlSvVShmFDbw1oum9QS  https://p.scdn.co/mp3-preview/44156f608cdbaec8...
# 2  46vJQ8zGlk5ROgQAS7FggF  https://p.scdn.co/mp3-preview/99b572ea9fbff34f...
# 3  7s7tnZE05RMouEnwcUhqQo  https://p.scdn.co/mp3-preview/d5c74163c61867f2...
# 4  0tV8pOpiNsKqUys0ilUcXz  https://p.scdn.co/mp3-preview/21b2fabb6435c0b7...
# 5  3O37piDdI2kyDnhJrPmZs0  https://p.scdn.co/mp3-preview/c67893b97287d746...
# 6  6pzsnbNRn8pm84lLvppo4l  https://p.scdn.co/mp3-preview/cef787e986c72dc8...
# 7  7daI4h2h7PZ5Rl858G1YMf  https://p.scdn.co/mp3-preview/6998580a10e9aeab...
# 8  7FI63EqRLE5SFcfViWIASS  https://p.scdn.co/mp3-preview/fdf1bc25b336dcc6...
# 9  4rmPQGwcLQjCoFq5NrTA0D  https://p.scdn.co/mp3-preview/f16e6a893a8a7322...

# %%
tracks_playlist = df_snippets_playlist['track_id']

df_tracks_playlist = df_tracks[df_tracks["track_id"].isin(tracks_playlist)]

df_tracks_playlist.drop_duplicates(subset=['track_id'], keep='first', inplace=True)

# to be sure the information is in the good order
df_tracks_playlist.set_index('track_id',inplace=True)

df_tracks_playlist=df_tracks_playlist.reindex(index = tracks_playlist)

df_tracks_playlist.reset_index(inplace=True)
df_tracks_playlist
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                  track_id category_id                 album_name  \
# 0  3y4uSQwxHckyRcvafEilkN         pop            Fallen so Young
# 1  0KURlSvVShmFDbw1oum9QS         pop                       2002
# 2  46vJQ8zGlk5ROgQAS7FggF         pop                Yellow Bird
# 3  7s7tnZE05RMouEnwcUhqQo         pop                      Betty
# 4  0tV8pOpiNsKqUys0ilUcXz         pop         Cheers To The Fall
# 5  3O37piDdI2kyDnhJrPmZs0         pop  Jaiye (Time of Our Lives)
# 6  6pzsnbNRn8pm84lLvppo4l         pop                       Wow.
# 7  7daI4h2h7PZ5Rl858G1YMf         pop                      Limbo
# 8  7FI63EqRLE5SFcfViWIASS         pop                 D.I.L.Y.D.
# 9  4rmPQGwcLQjCoFq5NrTA0D         pop                Uptown Funk
#
#               artist_name        playlist_name                 track_name  \
# 0        Declan J Donovan        Acoustic Hits            Fallen so Young
# 1    Anne-Marie,Jay Pryor  Massive Pop Remixes     2002 - Jay Pryor Remix
# 2           Ben Stevenson        Acoustic Hits                Yellow Bird
# 3               Betty Who            Fresh Pop                   Language
# 4               Andra Day        Soft Pop Hits                    Rise Up
# 5                 LADIPOE              Afropop  Jaiye (Time of Our Lives)
# 6              Macy Ellen        Hot Acoustics                       Wow.
# 7               Supermoon           Troubadour                      Limbo
# 8                  KAWALA         Pop Acoustic               Mighty River
# 9  Mark Ronson,Bruno Mars            Retro Pop                Uptown Funk
#
#                               track_uri  duration_ms  track_popularity  \
# 0  spotify:track:3y4uSQwxHckyRcvafEilkN       232164                67
# 1  spotify:track:0KURlSvVShmFDbw1oum9QS       183078                53
# 2  spotify:track:46vJQ8zGlk5ROgQAS7FggF       222842                37
# 3  spotify:track:7s7tnZE05RMouEnwcUhqQo       190117                60
# 4  spotify:track:0tV8pOpiNsKqUys0ilUcXz       253342                76
# 5  spotify:track:3O37piDdI2kyDnhJrPmZs0       181212                45
# 6  spotify:track:6pzsnbNRn8pm84lLvppo4l       192334                32
# 7  spotify:track:7daI4h2h7PZ5Rl858G1YMf       172137                15
# 8  spotify:track:7FI63EqRLE5SFcfViWIASS       162857                43
# 9  spotify:track:4rmPQGwcLQjCoFq5NrTA0D       270627                35
#
#    acousticness  danceability  energy  valence    tempo  instrumentalness  \
# 0       0.85200         0.552   0.356   0.1960  109.763          0.000000
# 1       0.13100         0.759   0.868   0.7040  117.953          0.000019
# 2       0.68300         0.485   0.353   0.0706  114.064          0.396000
# 3       0.55600         0.817   0.731   0.7360  113.982          0.000151
# 4       0.80500         0.398   0.316   0.1740  118.582          0.000000
# 5       0.55400         0.703   0.725   0.7100  111.948          0.000344
# 6       0.60700         0.664   0.205   0.1600  120.035          0.000000
# 7       0.13100         0.825   0.703   0.8690  115.029          0.000008
# 8       0.87500         0.912   0.311   0.3400  112.009          0.000000
# 9       0.00966         0.853   0.681   0.9300  115.004          0.000057
#
#    key  mode  liveness  loudness  speechiness
# 0   10     1    0.1730    -7.608       0.0270
# 1    4     1    0.2260    -4.269       0.0486
# 2    6     0    0.1060   -11.212       0.0296
# 3    9     0    0.4650    -4.436       0.0708
# 4    1     1    0.2950    -7.031       0.0368
# 5    3     0    0.1500    -6.814       0.0535
# 6    6     0    0.0968   -10.901       0.0575
# 7    5     1    0.2420    -7.385       0.0441
# 8   11     1    0.1050    -8.705       0.1850
# 9    0     1    0.0233    -5.003       0.0888

# %%
df_tracks_playlist.to_csv(creating_playlist_folder+ "playlist_high_low_extreme_info.csv", index=False)

# %% [markdown]
# #### Descriptive Statistics

# %%
df_tracks_playlist[['energy','valence','tempo']].describe()
# Out:
#           energy    valence       tempo
# count  10.000000  10.000000   10.000000
# mean    0.524900   0.488960  114.836900
# std     0.237142   0.330913    3.235847
# min     0.205000   0.070600  109.763000
# 25%     0.325250   0.179500  112.502250
# 50%     0.518500   0.522000  114.534000
# 75%     0.719500   0.729500  117.222000
# max     0.868000   0.930000  120.035000

# %% [markdown]
# #### Boxplot

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots Audio Features : Energy, Valence, and Tempo for Playlist with Low Absolute Difference in"+
            "Energy, Valence, and Tempo for Category "+category+".")
    
sns.boxplot(data=df_tracks_playlist[['energy', 'valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter PLot Showing Tracks of Playlist high_low_extreme

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy,hue = df_tracks_playlist.track_name, s = 200)
ax.set_title('Energy x Valence for tracks in Playlist high_low_extreme.\n', fontsize=16)
# ax.legend(loc = 'best')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.25),ncol=3, fancybox=True, shadow=True)

# %% [markdown]
# #### 3D Scatter plot showing tracks

# %%
df_track_names = df_tracks_playlist.track_name.to_frame()

df_track_names.reset_index(inplace=True)

df_track_names
# Out:
#    index                 track_name
# 0      0            Fallen so Young
# 1      1     2002 - Jay Pryor Remix
# 2      2                Yellow Bird
# 3      3                   Language
# 4      4                    Rise Up
# 5      5  Jaiye (Time of Our Lives)
# 6      6                       Wow.
# 7      7                      Limbo
# 8      8               Mighty River
# 9      9                Uptown Funk

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = df_tracks_playlist.valence
ys = df_tracks_playlist.energy
zs = df_tracks_playlist.tempo


ax.scatter(xs, ys, zs, s=200,c = df_track_names['index'], cmap=cm.tab10)
ax.set_title('Energy x Valence x Tempo for tracks in Playlist high_low_extreme.\n', fontsize=16)

ax.set_xlabel('Valence')
ax.set_ylabel('Energy')
ax.set_zlabel('Tempo')


plt.show()

# %% [markdown]
# #### Density Plots

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots energy, valence, and tempo for Playlist high_low_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['energy', 'valence', 'tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Analysis Absolute Difference Between Audio Tracks - Playlist high_low_extreme

# %%
list_current = df_snippets_playlist['track_id'][:-1].tolist()
list_next = df_snippets_playlist['track_id'][1:].tolist()

df_diff_playlist = pd.DataFrame(data = {'current_track':list_current,'next_track':list_next})
df_diff_playlist["current_track-next_track"] = df_diff_playlist['current_track']+'_'+df_diff_playlist['next_track']
df_diff_playlist.head()
# Out:
#             current_track              next_track  \
# 0  3y4uSQwxHckyRcvafEilkN  0KURlSvVShmFDbw1oum9QS
# 1  0KURlSvVShmFDbw1oum9QS  46vJQ8zGlk5ROgQAS7FggF
# 2  46vJQ8zGlk5ROgQAS7FggF  7s7tnZE05RMouEnwcUhqQo
# 3  7s7tnZE05RMouEnwcUhqQo  0tV8pOpiNsKqUys0ilUcXz
# 4  0tV8pOpiNsKqUys0ilUcXz  3O37piDdI2kyDnhJrPmZs0
#
#                         current_track-next_track
# 0  3y4uSQwxHckyRcvafEilkN_0KURlSvVShmFDbw1oum9QS
# 1  0KURlSvVShmFDbw1oum9QS_46vJQ8zGlk5ROgQAS7FggF
# 2  46vJQ8zGlk5ROgQAS7FggF_7s7tnZE05RMouEnwcUhqQo
# 3  7s7tnZE05RMouEnwcUhqQo_0tV8pOpiNsKqUys0ilUcXz
# 4  0tV8pOpiNsKqUys0ilUcXz_3O37piDdI2kyDnhJrPmZs0

# %%
list_sequences = df_diff_playlist["current_track-next_track"].tolist()

# %%
audio_features_df = df_tracks_diff[df_tracks_diff["current_track-next_track"].isin(list_sequences)]

# %%
df_tracks_playlist = pd.merge(df_diff_playlist,audio_features_df,left_on="current_track-next_track", right_on="current_track-next_track")

# %%
df_tracks_playlist
# Out:
#             current_track              next_track  \
# 0  3y4uSQwxHckyRcvafEilkN  0KURlSvVShmFDbw1oum9QS
# 1  0KURlSvVShmFDbw1oum9QS  46vJQ8zGlk5ROgQAS7FggF
# 2  46vJQ8zGlk5ROgQAS7FggF  7s7tnZE05RMouEnwcUhqQo
# 3  7s7tnZE05RMouEnwcUhqQo  0tV8pOpiNsKqUys0ilUcXz
# 4  0tV8pOpiNsKqUys0ilUcXz  3O37piDdI2kyDnhJrPmZs0
# 5  3O37piDdI2kyDnhJrPmZs0  6pzsnbNRn8pm84lLvppo4l
# 6  6pzsnbNRn8pm84lLvppo4l  7daI4h2h7PZ5Rl858G1YMf
# 7  7daI4h2h7PZ5Rl858G1YMf  7FI63EqRLE5SFcfViWIASS
# 8  7FI63EqRLE5SFcfViWIASS  4rmPQGwcLQjCoFq5NrTA0D
#
#                         current_track-next_track  diff_acousticness  \
# 0  3y4uSQwxHckyRcvafEilkN_0KURlSvVShmFDbw1oum9QS            0.72100
# 1  0KURlSvVShmFDbw1oum9QS_46vJQ8zGlk5ROgQAS7FggF            0.55200
# 2  46vJQ8zGlk5ROgQAS7FggF_7s7tnZE05RMouEnwcUhqQo            0.12700
# 3  7s7tnZE05RMouEnwcUhqQo_0tV8pOpiNsKqUys0ilUcXz            0.24900
# 4  0tV8pOpiNsKqUys0ilUcXz_3O37piDdI2kyDnhJrPmZs0            0.25100
# 5  3O37piDdI2kyDnhJrPmZs0_6pzsnbNRn8pm84lLvppo4l            0.05300
# 6  6pzsnbNRn8pm84lLvppo4l_7daI4h2h7PZ5Rl858G1YMf            0.47600
# 7  7daI4h2h7PZ5Rl858G1YMf_7FI63EqRLE5SFcfViWIASS            0.74400
# 8  7FI63EqRLE5SFcfViWIASS_4rmPQGwcLQjCoFq5NrTA0D            0.86534
#
#    diff_danceability  diff_energy  diff_valence  diff_tempo  \
# 0              0.207        0.512        0.5080       8.190
# 1              0.274        0.515        0.6334       3.889
# 2              0.332        0.378        0.6654       0.082
# 3              0.419        0.415        0.5620       4.600
# 4              0.305        0.409        0.5360       6.634
# 5              0.039        0.520        0.5500       8.087
# 6              0.161        0.498        0.7090       5.006
# 7              0.087        0.392        0.5290       3.020
# 8              0.059        0.370        0.5900       2.995
#
#    diff_instrumentalness  diff_key  diff_mode  diff_liveness  diff_loudness  \
# 0               0.000019       6.0        0.0         0.0530          3.339
# 1               0.395981       2.0        1.0         0.1200          6.943
# 2               0.395849       3.0        0.0         0.3590          6.776
# 3               0.000151       8.0        1.0         0.1700          2.595
# 4               0.000344       2.0        1.0         0.1450          0.217
# 5               0.000344       3.0        0.0         0.0532          4.087
# 6               0.000008       1.0        1.0         0.1452          3.516
# 7               0.000008       6.0        0.0         0.1370          1.320
# 8               0.000057      11.0        0.0         0.0817          3.702
#
#    diff_speechiness  is_good_sequence
# 0            0.0216                 0
# 1            0.0190                 0
# 2            0.0412                 0
# 3            0.0340                 0
# 4            0.0167                 0
# 5            0.0040                 0
# 6            0.0134                 0
# 7            0.1409                 0
# 8            0.0962                 0

# %% [markdown]
# #### Descriptive Statistics absolute difference 2-tracks

# %%
df_tracks_playlist[['diff_energy','diff_valence','diff_tempo']].describe()
# Out:
#        diff_energy  diff_valence  diff_tempo
# count     9.000000      9.000000    9.000000
# mean      0.445444      0.586978    4.722556
# std       0.064168      0.068367    2.626889
# min       0.370000      0.508000    0.082000
# 25%       0.392000      0.536000    3.020000
# 50%       0.415000      0.562000    4.600000
# 75%       0.512000      0.633400    6.634000
# max       0.520000      0.709000    8.190000

# %% [markdown]
# #### Boxplots absolute difference 2-tracks

# %%
fig, axs = plt.subplots(1, 2, figsize = (10,6))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)

fig.suptitle("Boxplots audio features : diff_energy, diff_valence, and diff_tempo.")
    
sns.boxplot(data=df_tracks_playlist[['diff_energy', 'diff_valence']], orient="v", palette="Set2",ax = axs[0])    
sns.boxplot(data=df_tracks_playlist[['diff_tempo']], orient="v", palette="Set1", ax = axs[1])

# %% [markdown]
# #### Scatter plots absolute difference 2-tracks Valence x Energy Playlist high_low_extreme

# %%
# sns.scatterplot(df_tracks_playlist.valence, df_tracks_playlist.energy)
ax = sns.scatterplot(df_tracks_playlist.diff_valence, df_tracks_playlist.diff_energy, hue = df_tracks_playlist["current_track-next_track"], s = 200, cmap=cm.tab10)
# Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.50),ncol=2, fancybox=True, shadow=True)

# %% [markdown]
# #### Density PLots absolute difference 2-tracks - energy, valence, and tempo

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.4)
    # title   
fig.suptitle("Density plots absolute difference 2-tracks diff_energy, diff_valence, and diff_tempo for Playlist high_low_extreme - Category "+category+".")
    
sns.distplot(df_tracks_playlist.diff_energy,ax=axs[0])
    
sns.distplot(df_tracks_playlist.diff_valence,ax=axs[1])
    
sns.distplot(df_tracks_playlist.diff_tempo,ax=axs[2])
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Density Plots of All Audio features absolute difference 2-tracks

# %%
category_id = category
category_id_df = df_tracks_playlist
plot_dist_categories_diff_features(category_id, category_id_df, images_folder)
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation Heatmap absolute difference 2-tracks

# %%
plt.figure(figsize=(10,10))
corr = df_tracks_playlist.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 20, sep=20, as_cmap=True),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### Pairplots absolute difference 2-tracks energy, valence, and tempo

# %%
sns.pairplot(df_tracks_playlist[['diff_energy', 'diff_valence', 'diff_tempo']], diag_kind = 'kde')
# Out:
# C:\Users\s178288\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
